# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmed-zunaira/APS360_Project/blob/main/APS360_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # APS360 Project: Anomaly Detection of Phytoplankton
#
#
# ## 1. Install
#
# #### Install Python packages

# %%
# !git clone https://github.com/ahmed-zunaira/APS360_Project.git
# Out:
# Cloning into 'APS360_Project'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 28 (delta 6), reused 17 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 8.63 KiB | 4.31 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd APS360_Project
# Out:
# /content/APS360_Project

# %%
# !pip install earthaccess xarray netCDF4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 119.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.9/203.9 kB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 89.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 99.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.6.0 which is incompatible.
# ...

# %% [markdown]
# #### Install Louvain
#
# Outside of Colab, you could do this with
#
# ```bash
# pip install --user louvain
# ```

# %%
import scprep
scprep.io.download.download_google_drive("1cpwiEVJhEhXPNvO3K6-jxEg3k3H-d1Sg", "python_igraph-0.7.1.post6-cp36-cp36m-linux_x86_64.whl")
scprep.io.download.download_google_drive("1IsD8uMy_7g-yydMRy2W6Mc4XLqXaF6ea", "louvain-0.6.1-cp36-cp36m-linux_x86_64.whl")

# %%
# !pip install --user python_igraph-0.7.1.post6-cp36-cp36m-linux_x86_64.whl louvain-0.6.1-cp36-cp36m-linux_x86_64.whl

# %% [markdown]
# #### Install velocyto
#
# Outside of Colab, you could do this with
#
# ```bash
# pip install --user velocyto
# ```

# %%
scprep.io.download.download_google_drive('12upnl0Cq4z2diGBWUtXjZzgVkfE-A06B', 'pysam-0.15.3-cp36-cp36m-linux_x86_64.whl')
scprep.io.download.download_google_drive('12fNIfQlZgDvPZ6YoILjN16oIyhjgKfva', 'velocyto-0.17.17-cp36-cp36m-linux_x86_64.whl')

# %%
# !pip install --user pysam-0.15.3-cp36-cp36m-linux_x86_64.whl velocyto-0.17.17-cp36-cp36m-linux_x86_64.whl

# %% [markdown]
# #### Install R packages (Splatter and Slingshot)
#
# Outside of Colab, you could do this in Python with
#
# ```python
# import scprep
# scprep.run.splatter.install()
# scprep.run.slingshot.install()
# ```
# or if you prefer to work in R,
#
# ```R
# install.packages('BiocManager')
# BiocManager::install('splatter')
# BiocManager::install('slingshot')
# ```

# %%
scprep.io.download.download_google_drive('1VuddKA7Xa23NAFKvRUmtuND16eEMHL9z',
                                         '/content/r_packages.tar.gz')
# !tar xzf /content/r_packages.tar.gz && rm /content/r_packages.tar.gz
# !apt-get install -yqq libgsl-dev=2.4+dfsg-6
# !pip install --user --upgrade rpy2
# !echo "R_LIBS_USER='/content/.r_packages'" >> ~/.Renviron
# !R -e "BiocManager::install('splatter')"

# %% [markdown]
# ## 2. Analysis
#
# Go forth and machine learn!

# %%
# !python src/download_modis.py

# !python src/data_processing.py

# !python src/train.py
# Out:
# Enter your Earthdata Login username: zun23
# Enter your Earthdata password:
# /usr/local/lib/python3.12/dist-packages/earthaccess/results.py:348: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   self["size"] = self.size()
# /usr/local/lib/python3.12/dist-packages/earthaccess/results.py:375: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   Size(MB): {self.size()}
# Found 46 granules. Starting download...
# /usr/local/lib/python3.12/dist-packages/earthaccess/store.py:838: FutureWarning: As of version 1.0, `DataGranule.size` will be accessed as an attribute; e.g. use `DataCollection.size` **not** `DataCollection.size()`
#   total_size = round(sum(granule.size() for granule in granules) / 1024, 2)
# Traceback (most recent call last):
# ...
